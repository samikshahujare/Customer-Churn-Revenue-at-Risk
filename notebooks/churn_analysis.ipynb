# %% [markdown]
# # Churn Analysis Walkthrough
#
# Mirrors the production training pipeline in `training/train.py`.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))
from app.utils.preprocessing import load_raw, clean_dataframe
from app.utils.feature_engineering import add_engineered_features
from training.config import RAW_CSV
df = add_engineered_features(clean_dataframe(load_raw(RAW_CSV)))
df.head()

# %%
df['Churn'].value_counts(normalize=True)

# %%
from training.train import main
metrics = main()
metrics
